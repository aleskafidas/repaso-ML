# %%
import pandas as pd
df =pd.read_csv(r'C:\Users\Alejandro\Desktop\proeycto 2\properties_colombia_train.csv')
df.head()
# Out:
#    Unnamed: 0                        id    ad_type  start_date    end_date  \
# 0      861131  CScTjaFiP6yCzS8tFX0ZVA==  Propiedad  2020-12-14  9999-12-31
# 1      200972  DlCxox9+FuugkxS2kBVfJg==  Propiedad  2020-09-16  2021-05-14
# 2      554622  yitN1AigL45gh/K2YSF8rw==  Propiedad  2020-08-19  2020-08-20
# 3      540321  hELQ9njwODbLMpATXieRdQ==  Propiedad  2020-11-23  2020-11-30
# 4      448920  aBCtKT7LDzt2CxJQ+gVFEA==  Propiedad  2020-10-06  2020-10-07
#
#    created_on       lat        lon        l1            l2  ... surface_total  \
# 0  2020-12-14  6.203000 -75.572000  Colombia     Antioquia  ...           NaN
# 1  2020-09-16  4.722748 -74.073115  Colombia  Cundinamarca  ...           NaN
# 2  2020-08-19  4.709000 -74.030000  Colombia  Cundinamarca  ...           NaN
# 3  2020-11-23       NaN        NaN  Colombia     Santander  ...           NaN
# 4  2020-10-06       NaN        NaN  Colombia     Antioquia  ...           NaN
#
# ...

# %%
mean_price = int(df.price.mean())

df1['Promedio'] = df1['price'].apply(lambda x: 1 if x > mean_price else 0)

# %%
df.Promedio.value_counts()
# Out:
# 0    151191
# 1     46358
# Name: Promedio, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# id                      0
# ad_type                 0
# start_date              0
# end_date                0
# created_on              0
# lat                 49498
# lon                 49498
# l1                      0
# l2                      0
# l3                  11032
# l4                 152182
# l5                 170140
# l6                 190682
# rooms              170012
# bedrooms           157024
# bathrooms           41082
# surface_total      190575
# surface_covered    187747
# price                  63
# currency               67
# price_period       161578
# title                   1
# description           121
# property_type           0
# operation_type          0
# geometry                0
# Promedio                0
# dtype: int64

# %%
df.drop(['l4','l5', 'l6', 'Unnamed: 0', 'surface_total', 'rooms'], axis=1)
# Out:
#                               id    ad_type  start_date    end_date  \
# 0       CScTjaFiP6yCzS8tFX0ZVA==  Propiedad  2020-12-14  9999-12-31
# 1       DlCxox9+FuugkxS2kBVfJg==  Propiedad  2020-09-16  2021-05-14
# 2       yitN1AigL45gh/K2YSF8rw==  Propiedad  2020-08-19  2020-08-20
# 3       hELQ9njwODbLMpATXieRdQ==  Propiedad  2020-11-23  2020-11-30
# 4       aBCtKT7LDzt2CxJQ+gVFEA==  Propiedad  2020-10-06  2020-10-07
# ...                          ...        ...         ...         ...
# 197544  u2M1W+AwbEZlRdmphDOuZg==  Propiedad  2020-10-27  9999-12-31
# 197545  m0P17AlA6Sp+uvJTI3x3AA==  Propiedad  2020-11-27  2020-12-09
# 197546  nSRnmPZIwE92m/FQv8ktVQ==  Propiedad  2020-10-28  2021-01-02
# 197547  cbYIZxxFHsXvvkixg5+DBQ==  Propiedad  2020-08-14  2020-08-14
# 197548  ivrCGYtvreFxwv/BHSLWTg==  Propiedad  2020-10-06  2020-11-27
#
#         created_on        lat        lon        l1               l2  \
# 0       2020-12-14   6.203000 -75.572000  Colombia        Antioquia
# ...

# %%
df['l3'].fillna('Medellín' or Cali or 'Bogotá D.C' )
# Out:
# 0             Medellín
# 1           Bogotá D.C
# 2           Bogotá D.C
# 3          Bucaramanga
# 4             Medellín
#               ...
# 197544      Bogotá D.C
# 197545      Bogotá D.C
# 197546            Cali
# 197547      Bogotá D.C
# 197548    Barranquilla
# Name: l3, Length: 197549, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1 non-null      float64
#  1   1       1 non-null      float64
#  2   2       1 non-null      float64
#  3   3       1 non-null      float64
# dtypes: float64(4)
# memory usage: 160.0 bytes

# %%
df['rooms'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ALEJAN~1\AppData\Local\Temp/ipykernel_10736/3964000666.py in <module>
# ----> 1 df['rooms'].isnull().sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'rooms'

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(1, 4))
df['rooms'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ALEJAN~1\AppData\Local\Temp/ipykernel_10736/3664063067.py in <module>
#       1 import numpy as np
#       2 df = pd.DataFrame(np.random.rand(1, 4))
# ----> 3 df['rooms'].isnull().sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
# ...

# %%
from matplotlib.style import context
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='whitegrid', context='notebook')
cols = ['DIS', 'INDUS', 'CRIM', 'RM', 'MEDV']#SE ESCOGEN LAS VARIABLES
sns.pairplot(df[cols], height=2.5)#grafico y estilo del grafico
plt.show()
